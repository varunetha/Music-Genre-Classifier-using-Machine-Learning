# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import librosa.display
from IPython.display import Audio

# %%
music_data = pd.read_csv(r"D:\Practice PPS\Mini Project\file.csv") 
music_data.head(1000)
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0    blues.00000.wav  661794          0.350088         0.088757  0.130228
# 1    blues.00001.wav  661794          0.340914         0.094980  0.095948
# 2    blues.00002.wav  661794          0.363637         0.085275  0.175570
# 3    blues.00003.wav  661794          0.404785         0.093999  0.141093
# 4    blues.00004.wav  661794          0.308526         0.087841  0.091529
# ..               ...     ...               ...              ...       ...
# 995   rock.00095.wav  661794          0.352063         0.080487  0.079486
# 996   rock.00096.wav  661794          0.398687         0.075086  0.076458
# 997   rock.00097.wav  661794          0.432142         0.075268  0.081651
# 998   rock.00098.wav  661794          0.362485         0.091506  0.083860
# 999   rock.00099.wav  661794          0.358401         0.085884  0.054454
#
#       rms_var  spectral_centroid_mean  spectral_centroid_var  \
# ...

# %%
music_data['label'].value_counts()
# Out:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: count, dtype: int64

# %%
path = r'D:\Practice PPS\Mini Project\genres_original\blues\blues.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path)   
print("Blues")
# Out:
# Blues

# %%
path = r"D:\Practice PPS\Mini Project\genres_original\metal\metal.00000.wav"
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path) 
  
print("Metal")
# Out:
# Metal

# %%
path = r"D:\Practice PPS\Mini Project\genres_original\pop\pop.00000.wav"
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path) 
  
print("Pop")
# Out:
# Pop

# %%
path =  r"D:\Practice PPS\Mini Project\genres_original\hiphop\hiphop.00000.wav"
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path) 
  
print("HipHop")
# Out:
# HipHop

# %%
path = r'D:\Practice PPS\Mini Project\genres_original\jazz\jazz.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path)   
print("Jazz")
# Out:
# Jazz

# %%
path = r'D:\Practice PPS\Mini Project\genres_original\classical\classical.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path)   
print("Classical")
# Out:
# Classical

# %%
path = r'D:\Practice PPS\Mini Project\genres_original\country\country.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path)   
print("Country")
# Out:
# Country

# %%
path = r'D:\Practice PPS\Mini Project\genres_original\disco\disco.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path)   
print("Disco")
# Out:
# Disco

# %%
path = r'D:\Practice PPS\Mini Project\genres_original\reggae\reggae.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path)   
print("Reggae")
# Out:
# Reggae

# %%
path = r'D:\Practice PPS\Mini Project\genres_original\rock\rock.00000.wav'
plt.figure(figsize=(14, 5)) 
x, sr = librosa.load(path) 
librosa.display.waveshow(x, sr=sr) 
Audio(path)   
print("Rock")
# Out:
# Rock

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
music_data['label'] = label_encoder.fit_transform(music_data['label'])

# %%
X = music_data.drop(['label','filename'],axis=1) 
y = music_data['label']

# %%
cols = X.columns 
minmax = preprocessing.MinMaxScaler() 
np_scaled = minmax.fit_transform(X) 

# new data frame with the new scaled data. 
X = pd.DataFrame(np_scaled, columns = cols)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=111) 
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((700, 58), (300, 58), (700,), (300,))

# %%
from sklearn.metrics import accuracy_score 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LogisticRegression 
import catboost as cb 
from xgboost import XGBClassifier 

rf = RandomForestClassifier(n_estimators=1000, max_depth=10, random_state=0) 
cbc = cb.CatBoostClassifier(verbose=0, eval_metric='Accuracy', loss_function='MultiClass') 
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05) 

for clf in (rf, cbc, xgb): 
	clf.fit(X_train, y_train) 
	preds = clf.predict(X_test) 
	print(clf.__class__.__name__,accuracy_score(y_test, preds))
# Out:
# RandomForestClassifier 0.78
# CatBoostClassifier 0.8333333333333334
# XGBClassifier 0.7833333333333333

# %%
import tensorflow.keras as keras 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import *

model = Sequential() 

model.add(Flatten(input_shape=(58,))) 
model.add(Dense(256, activation='relu')) 
model.add(BatchNormalization()) 
model.add(Dense(128, activation='relu')) 
model.add(Dropout(0.3)) 
model.add(Dense(10, activation='softmax')) 
model.summary()
# Out:
# c:\Users\harsh\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 58)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        15,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# ...

# %%
adam = keras.optimizers.Adam(learning_rate=1e-4)

model.compile(
    optimizer=adam, 
    loss="sparse_categorical_crossentropy", 
    metrics=["accuracy"]
)

hist = model.fit(
    X_train, y_train, 
    validation_data=(X_test, y_test), 
    epochs=100, 
    batch_size=32
)
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1452 - loss: 2.4408 - val_accuracy: 0.1300 - val_loss: 2.2766
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2524 - loss: 2.1434 - val_accuracy: 0.1400 - val_loss: 2.2521
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2986 - loss: 1.9074 - val_accuracy: 0.1767 - val_loss: 2.2270
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3339 - loss: 1.7945 - val_accuracy: 0.2167 - val_loss: 2.1994
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4262 - loss: 1.6554 - val_accuracy: 0.2600 - val_loss: 2.1686
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4517 - loss: 1.5564 - val_accuracy: 0.3233 - val_loss: 2.1322
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4683 - loss: 1.5515 - val_accuracy: 0.3733 - val_loss: 2.0904
# Epoch 8/100
# ...

# %%
test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1) 
print(f"Test accuracy: {test_accuracy}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8030 - loss: 0.6631
# Test accuracy: 0.7799999713897705

# %%
fig, axs = plt.subplots(2,figsize=(10,10)) 
  
# accuracy  
axs[0].plot(hist.history["accuracy"], label="train") 
axs[0].plot(hist.history["val_accuracy"], label="test")     
axs[0].set_ylabel("Accuracy") 
axs[0].legend() 
axs[0].set_title("Accuracy") 
      
# Error  
axs[1].plot(hist.history["loss"], label="train") 
axs[1].plot(hist.history["val_loss"], label="test")     
axs[1].set_ylabel("Error") 
axs[1].legend() 
axs[1].set_title("Error") 
      
plt.show()
